# %%
import pandas as pd

# %%
df = pd.read_excel("C:/Users/accur/Downloads/Serial No.xlsx",index_col=None)

# %%
from mongodb.mongodb_connection import mongodbclient

# %%
obj= mongodbclient()
# Out:
# [ 2026-08-18 16:02:16,904 ] root - INFO - mongodb connection was established successfully

# %%
data = {
    "product_name": "electro cardiography",
    "product_id": "ecg",
    "model_no": "12-s zoncare",
    "lot_no": "0000",
    "quantity": 39,
    "serial_numbers": [
        "D6282141CTS04N0022",
        "D6282141CTS04N0045",
        "D6282141CTS04N0081",
        "D6282141CTS04N0044",
        "D6282141CTS04N0027",
        "D6282141CTS04N0014",
        "D6282141CTS04N0008",
        "D6282141CTS04N0002",
        "D6282141CTS04N0033",
        "D6282141CTS04N0009",
        "D6282141CTS04N0010",
        "D6282141CTS04N0015",
        "D6282141CTS04N0037",
        "D6282141CTS04N0048",
        "D6282141CTS04N0020",
        "D6282141CTS04N0031",
        "D6282141CTS04N0019",
        "D6282141CTS04N0028",
        "D6282141CTS04N0042",
        "D6282141CTS04N0017",
        "D6282141CTS04N0035",
        "D6282141CTS04N0021",
        "D6282141CTS04N0023",
        "D6282141CTS04N0029",
        "D6282141CTS04N0040",
        "D6282141CTS04N0038",
        "D6282141CTS04N0024",
        "D6282141CTS04N0046",
        "D6282141CTS04N0007",
        "D6282141CTS04N0047",
        "D6282141CTS04N0006",
        "D6282141CTS04N0030",
        "D6282141CTS04N0004",
        "D6282141CTS04N0050",
        "D6282141CTS04N0003",
        "D6282141CTS04N0034",
        "D6282141CTS04N0001",
        "D6282141CTS04N0026",
        "D6282141CTS04N0016"
    ],
    "supplier": "Acer Biomedicals",
    "supplier_address": "Noida",
    "purchase_date": "2026-08-17",
    "price": "26000",
    "tax_rate": 5
}

# %%
obj.add(collection_name = "inventory",dictionary=data)
# Out:
# [ 2026-08-18 16:04:54,479 ] root - INFO - document inserted with id: 6a84354eea30388c461ea5d9
# ObjectId('6a84354eea30388c461ea5d9')
